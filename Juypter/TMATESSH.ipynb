# %%
# !pkill -9 tmate
# !sudo apt install tmate nano aria2 -y -q &>/dev/null && rm -rf /tmp/tmate.sock sample_data
# !unset TMUX && ssh-keygen -t rsa -N '' -f ~/.ssh/id_rsa <<< y &>/dev/null
# !tmate -S /tmp/tmate.sock new-session -d 
# !tmate -S /tmp/tmate.sock wait tmate-ready
# !tmate -S /tmp/tmate.sock display -p '#{tmate_ssh}'
# Out:
# ssh bmysbPJ4mwUY5t4zQZfbLQFD9@sfo2.tmate.io

# %%
# !killall nano byobu tmate perl git &>/dev/null

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
from threading import Event
Event().wait()
